# %%
import pandas as pd
# %matplotlib inline

# %%
work_dog = pd.read_csv('account_dog.csv',index_col=0) #прочитал отчет из Redash

dogovor = work_dog.loc[work_dog['dogovor::filter'] == True] #сделал датафрейм для договора
spec = work_dog.loc[work_dog['dogovor::filter'] == False] #сделал датафрейм для спец.предложения

done = pd.DataFrame(index = range(1500)) #создал датафрейм, где индекс = дни, столбцы = компании, значения = количество студентов 
                                         # из компании на i-тый день договора

for company in dogovor['name'].unique():
    one_company = dog.loc[dog['name'] == company].copy()
    lst = []
    for i in range(1500):
        val = one_company.loc[one_company['days_from_first_lesson'] <= i]['student_count'].tail(1).values.astype(int)[0]
        company = one_company['name'].head(1).values[0]
        lst.append(val)
    done[company] = lst
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-142-1aea08be61b2> in <module>()
#       8     lst = []
#       9     for i in range(1500):
# ---> 10         val = one_company.loc[one_company['days_from_first_lesson'] <= i]['student_count'].tail(1).values.astype(int)[0]
#      11         company = one_company['name'].head(1).values[0]
#      12         lst.append(val)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
dog.sort_values(by='cnt', ascending=False)['name'].unique()
# Out:
# array(['BIOCAD', 'MTS OOO (Спецпредложение)',
#        'Дирекция железнодорожных вокзалов - филиал ОАО РЖД', 'IKEA',
#        'Отключен от кор. обучения', 'AmRest', 'Playrix', 'Крок',
#        'Просвещение оффлайн', 'Air Astana', 'Wargaming', 'Иннова',
#        'Билайн', 'Леруа Мерлен', 'Нордголд Менеджмент (Nord Gold) ООО',
#        'Псевдокорп', 'Align Technologies',
#        'Корпоративная Академия Госкорпорации ',
#        'Московский городской педагогический университет (МГПУ)',
#        'ТС ЛЕНТА (LENTA)  контракт', 'Атомстрой', 'Страна.Греция',
#        'Comparex', 'Appodeal', 'Mercury ',
#        'Юникредит (Договор 8ур+Vimbox)', 'Tapcore ООО',
#        'Зептолаб (ZeptoLab) ООО', 'Rockwool (Роквул)', 'Playrix Украина',
#        'Ресторанная группа Бурова и Коккова/Пивная карта',
#        'Аванта Солюшенс ООО / Adecco', 'Данфосс ООО', 'Grundfors',
#        '(Siemens) Сименс Трансформаторы ООО', 'Волга-Днепр Техникс Москва',
# ...

# %%
lst = []
for company in dog.sort_values(by='cnt', ascending=False)['name'].unique():
    ttest = dog.loc[dog['name'] == company].copy()
    lst.append(ttest)

# %%
len(lst)
# Out:
# 871

# %%
l1 = lst[0:100]
l2 = lst[100:200]
l3 = lst[200:300]
l4 = lst[300:400]
l5 = lst[400:500]
l6 = lst[500:600]
l7 = lst[600:700]
l8 = lst[700:800]
l9 = lst[800:900]

# %%
for dfs in l1:
    lst = []
    for i in range(1500):
        val = dfs.loc[dfs['days_from_first_lesson'] <= i]['student_count'].tail(1).values.astype(int)[0]
        lst.append(val)
    company = dfs['name'].head(1).values[0]
    done[company] = lst
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-136-ad5dbbc899d0> in <module>()
#       2     lst = []
#       3     for i in range(1500):
# ----> 4         val = dfs.loc[dfs['days_from_first_lesson'] <= i]['student_count'].tail(1).values.astype(int)[0]
#       5         lst.append(val)
#       6     company = dfs['name'].head(1).values[0]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
for dfs in l2:
    lst = []
    for i in range(1500):
        val = dfs.loc[dfs['days_from_first_lesson'] <= i]['student_count'].tail(1).values.astype(int)[0]
        lst.append(val)
    company = dfs['name'].head(1).values[0]
    done[company] = lst

# %%
for dfs in l3:
    lst = []
    for i in range(1500):
        val = dfs.loc[dfs['days_from_first_lesson'] <= i]['student_count'].tail(1).values.astype(int)[0]
        lst.append(val)
    company = dfs['name'].head(1).values[0]
    done[company] = lst
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-139-49ad758a2569> in <module>()
#       3     lst = []
#       4     for i in range(1500):
# ----> 5         val = dfs.loc[dfs['days_from_first_lesson'] <= i]['student_count'].tail(1).values.astype(int)[0]
#       6         lst.append(val)
#       7     company = dfs['name'].head(1).values[0]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
for dfs in l4:
    lst = []
    for i in range(1500):
        val = dfs.loc[dfs['days_from_first_lesson'] <= i]['student_count'].tail(1).values.astype(int)[0]
        lst.append(val)
    company = dfs['name'].head(1).values[0]
    done[company] = lst
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-116-ca50f7be010c> in <module>()
#       3     lst = []
#       4     for i in range(1500):
# ----> 5         val = dfs.loc[dfs['days_from_first_lesson'] <= i]['student_count'].tail(1).values.astype(int)[0]
#       6         lst.append(val)
#       7     company = dfs['name'].head(1).values[0]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
for dfs in l5:
    lst = []
    for i in range(1500):
        val = dfs.loc[dfs['days_from_first_lesson'] <= i]['student_count'].tail(1).values.astype(int)[0]
        lst.append(val)
    company = dfs['name'].head(1).values[0]
    done[company] = lst
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-117-49974a9a8cd3> in <module>()
#       3     lst = []
#       4     for i in range(1500):
# ----> 5         val = dfs.loc[dfs['days_from_first_lesson'] <= i]['student_count'].tail(1).values.astype(int)[0]
#       6         lst.append(val)
#       7     company = dfs['name'].head(1).values[0]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
for dfs in l6:
    lst = []
    for i in range(1500):
        val = dfs.loc[dfs['days_from_first_lesson'] <= i]['student_count'].tail(1).values.astype(int)[0]
        lst.append(val)
    company = dfs['name'].head(1).values[0]
    done[company] = lst
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-118-8097228085f0> in <module>()
#       3     lst = []
#       4     for i in range(1500):
# ----> 5         val = dfs.loc[dfs['days_from_first_lesson'] <= i]['student_count'].tail(1).values.astype(int)[0]
#       6         lst.append(val)
#       7     company = dfs['name'].head(1).values[0]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
for dfs in l7:
    lst = []
    for i in range(1500):
        val = dfs.loc[dfs['days_from_first_lesson'] <= i]['student_count'].tail(1).values.astype(int)[0]
        lst.append(val)
    company = dfs['name'].head(1).values[0]
    done[company] = lst
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-119-a2258f682ccb> in <module>()
#       3     lst = []
#       4     for i in range(1500):
# ----> 5         val = dfs.loc[dfs['days_from_first_lesson'] <= i]['student_count'].tail(1).values.astype(int)[0]
#       6         lst.append(val)
#       7     company = dfs['name'].head(1).values[0]
#
# KeyboardInterrupt:

# %%
for dfs in l8:
    lst = []
    for i in range(1500):
        val = dfs.loc[dfs['days_from_first_lesson'] <= i]['student_count'].tail(1).values.astype(int)[0]
        lst.append(val)
    company = dfs['name'].head(1).values[0]
    done[company] = lst

# %%
for dfs in l9:
    lst = []
    for i in range(1500):
        val = dfs.loc[dfs['days_from_first_lesson'] <= i]['student_count'].tail(1).values.astype(int)[0]
        lst.append(val)
    company = dfs['name'].head(1).values[0]
    done[company] = lst
