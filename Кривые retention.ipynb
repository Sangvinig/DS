# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sp = pd.read_csv('ret_spec.csv',index_col=0)
dog = pd.read_csv('ret_dog.csv',index_col=0)

# %%
sp.drop('cohort_size', axis=1).T.plot()

# %%
dog.drop('cohort_size', axis=1).T.shape
# Out:
# (54, 30)

# %%
dog.drop('cohort_size', axis=1).T.plot()
